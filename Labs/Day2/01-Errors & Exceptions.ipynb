# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
try:
  x = float(input("Enter a number: "))
  y = float(input("Enter another number: "))

  z = x / y
except:
  print("Some error has ocuured")

# %%
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-0106664d39e8> in <module>()
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Exception Handling

# %%
# Example 1
var1=10
var2=0
result=var1/var2   # We can't divide any number by Zero. In case it is done, it will throw ZeroDivisionError which is predefined exception
print(result)
print('end')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-aa63a48c93eb> in <module>
#       2 var1=10
#       3 var2=0
# ----> 4 result=var1/var2   # We can't divide any number by Zero. In case it is done, it will throw ZeroDivisionError which is predefined exception
#       5 print(result)
#       6 print('end')
#
# ZeroDivisionError: division by zero

# %%
# Example 2
list1=[1,2,3,4]
print(list1[len(list1)])   # This will give IndexError as we have tried to access an index which is beyond the range
print(list1[-6])           # This will also give IndexError as we have tried to access an index which is beyond the range
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-76897246fea9> in <module>
#       1 # Example 2
#       2 list1=[1,2,3,4]
# ----> 3 print(list1[len(list1)])   # This will give IndexError as we have tried to access an index which is beyond the range
#       4 print(list1[-6])           # This will also give IndexError as we have tried to access an index which is beyond the range
#
# IndexError: list index out of range

# %%
# Example 3  -- Exception Handling

try:
    var1=10
    var2=0
    result=var1/var2 # This line will raise Zero Division Error Exception and then Python will search for exception handler block i.e. except block
    print(result)
except:              # The except block will handle the exception and prints the messages
    print('Some exception Occured')
    print('End')
# Out:
# Some exception Occured
# End

# %%
# Important Point :- Once the program flow comes out of try block and enters except block, it never goes back to try block

# %%
# Example 4  -- Value Error Exception Example

import sys
randomlist=['a',0,2]
for entry in randomlist:
    try:
        print("The entry is",entry)
        r=1/int(entry)
        break
    except:
        print("Oops!",sys.exc_info()[0],"occured")
        print("Next Entry")
        print()
        print("The reciprocal of",entry,"is",r)
# Out:
# The entry is a
# Oops! <class 'ValueError'> occured
# The entry is 0
# Oops! <class 'ZeroDivisionError'> occured
# The entry is 2

# %% [markdown]
# ## Try- Except-Else-Finally

# %%
# Example 6
try:
    var1=10
    var2=int(input('Enter the divisor: '))
    result=var1/var2
except:
    print('Some Exception Happened')
    print(sys.exc_info())
else:
    print('There was no exception')

finally:
    print('End')
# Out:
# Enter the divisor12
# There was no exception
# End

# %%
# Example 7 -- Multiple Except Blocks 
try:
    var1=10
    var2=0
    list1=[1,2,3]
    list1[3]=var1/var2
    print(list1[3])
except:
    print("Some unknown error has occured")    
except ZeroDivisionError:
    print('Numbers cant be divided by zero')
except ValueError:
    print('It is a value error')
except IndexError:
    print('The index is out of range')
# Out:
# Numbers cant be divided by zero

# %% [markdown]
# **Raising Exceptions**

# %%
raise NameError('HiThere')

# %% [markdown]
#  - If you need to determine whether an exception was raised but don’t intend to handle it
#    - a simpler form of the raise statement allows you to re-raise the exception

# %%
try:
     raise NameError('HiThere')
except NameError:
     print('An exception flew by!')
     raise
# Out:
# An exception flew by!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fbd80e0e5d05> in <module>()
#       1 try:
# ----> 2      raise NameError('HiThere')
#       3 except NameError:
#       4      print('An exception flew by!')
#       5      raise
#
# NameError: HiThere
